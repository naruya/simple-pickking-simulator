# %%
import random
import numpy as np
import cv2
import abc

from utils import layerize, overlay
from modules import OB, Shelf, Robot, World

import matplotlib.pyplot as plt
# %matplotlib inline
world = World(name="world")
plt.imshow(world.render())
plt.show()

for t in range(300):
    world.step()
del world
# Out:
# [I 08:48:35.270480 robot] state: 0
# [I 08:48:35.853639 robot] state: 1
# [I 08:49:57.001290 robot] state: 2
# [I 08:49:57.574537 robot] state: 2
# [I 08:49:58.151025 robot] state: 2
# [I 08:49:58.721720 robot] state: 2
# [I 08:49:59.294192 robot] state: 2
# [I 08:49:59.867444 robot] state: 2
# [I 08:50:00.438825 robot] state: 2
# [I 08:50:01.011079 robot] state: 2
# [I 08:50:01.585343 robot] state: 2
# [I 08:50:02.156045 robot] state: 2
# [I 08:50:02.729267 robot] state: 2
# [I 08:50:03.302545 robot] state: 2
# [I 08:50:03.872791 robot] state: 2
# [I 08:50:04.445136 robot] state: 2
# [I 08:50:05.018992 robot] state: 2
# [I 08:50:05.590269 robot] state: 2
# [I 08:50:06.163046 robot] state: 2
# [I 08:50:06.736799 robot] state: 2
# [I 08:50:07.308997 robot] state: 2
# [I 08:50:07.884704 robot] state: 2
# [I 08:50:08.458459 robot] state: 2
# [I 08:50:09.029648 robot] state: 2
# [I 08:50:09.602308 robot] state: 2
# [I 08:50:10.184014 robot] state: 2
# [I 08:50:10.754485 robot] state: 2
# ...
