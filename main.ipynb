# %%
from modules import World
import matplotlib.pyplot as plt
# %matplotlib inline

world = World(name="world")

view = world.render()
plt.imshow(view)
plt.show()

# %%
for t in range(300):
    world.step()
del world
# Out:
# [I 09:17:09.243607 robot] state: 0
# [I 09:17:09.830810 robot] state: 1
# [I 09:17:52.325988 robot] state: 1
# [I 09:18:45.787335 robot] state: 2
# [I 09:18:46.291491 robot] state: 2
# [I 09:18:46.795568 robot] state: 2
# [I 09:18:47.301054 robot] state: 2
# [I 09:18:47.805146 robot] state: 2
# [I 09:18:48.310217 robot] state: 2
# [I 09:18:48.814099 robot] state: 2
# [I 09:18:49.317949 robot] state: 2
# [I 09:18:49.823499 robot] state: 2
# [I 09:18:50.328450 robot] state: 2
# [I 09:18:50.833191 robot] state: 2
# [I 09:18:51.337854 robot] state: 2
# [I 09:18:51.841574 robot] state: 2
# [I 09:18:52.345444 robot] state: 2
# [I 09:18:52.849057 robot] state: 2
# [I 09:18:53.392630 robot] state: 2
# [I 09:18:53.905909 robot] state: 2
# [I 09:18:54.411263 robot] state: 2
# [I 09:18:54.916689 robot] state: 2
# [I 09:18:55.421453 robot] state: 2
# [I 09:18:55.927178 robot] state: 2
# [I 09:18:56.431710 robot] state: 2
# [I 09:18:56.937397 robot] state: 2
# [I 09:18:57.442593 robot] state: 2
# ...
